# %%
# %reset -f 
import os, sys, imp
sys.path.append('/home/seyedkazemi/codes/mskhelper/')
sys.path.append('/home/seyedkazemi/codes/Marconi100/DNN/')
import pandas as pd, numpy as np
import datetime, pytz
import data_provider, mohsenutils, m100_preprocessing_helper, flag_helper, autoencoder_helper
import imp 
from  matplotlib import pyplot as plt
import torch 
import torch.nn as nn
import torch.functional as f
from torch.utils.data import DataLoader, Dataset
from torchinfo import summary
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from contextlib import redirect_stdout
import json
import datetime, pytz
import random
import function_set as fn
from contextlib import redirect_stdout
from pickle import dump
imp.reload(data_provider)
imp.reload(mohsenutils)
imp.reload(m100_preprocessing_helper)
imp.reload(flag_helper)
imp.reload(autoencoder_helper)


autoencoder_helper.LSTM_AE_Complete(**{'grey_data_range':[16,35], 'grey_data_train_threshold':30, 'cuda':'2'})
autoencoder_helper.LSTM_AE_Complete(**{'grey_data_range':[16,35], 'grey_data_train_threshold':35, 'cuda':'3'})
autoencoder_helper.LSTM_AE_Complete(**{'grey_data_range':[1,25],  'grey_data_train_threshold':0,  'cuda':'2'})



autoencoder_helper.LSTM_AE_Complete(**{'grey_data_range':[1,25],  'grey_data_train_threshold':5,  'cuda':'3'})
autoencoder_helper.LSTM_AE_Complete(**{'grey_data_range':[1,25],  'grey_data_train_threshold':10, 'cuda':'2'})
autoencoder_helper.LSTM_AE_Complete(**{'grey_data_range':[1,25],  'grey_data_train_threshold':15, 'cuda':'3'})
                                                                                            
                                                                                            
autoencoder_helper.LSTM_AE_Complete(**{'grey_data_range':[11,35], 'grey_data_train_threshold':10, 'cuda':'3'})
autoencoder_helper.LSTM_AE_Complete(**{'grey_data_range':[11,35], 'grey_data_train_threshold':15, 'cuda':'2'})
autoencoder_helper.LSTM_AE_Complete(**{'grey_data_range':[11,35], 'grey_data_train_threshold':20, 'cuda':'3'})
autoencoder_helper.LSTM_AE_Complete(**{'grey_data_range':[11,35], 'grey_data_train_threshold':25, 'cuda':'2'})                                                                                            
                                                                                            
autoencoder_helper.LSTM_AE_Complete(**{'grey_data_range':[11,25], 'grey_data_train_threshold':25, 'cuda':'2'})
                                                                                            
autoencoder_helper.LSTM_AE_Complete(**{'grey_data_range':[11,25], 'grey_data_train_threshold':20, 'cuda':'3'})

autoencoder_helper.LSTM_AE_Complete(**{'grey_data_range':[1,25],  'grey_data_train_threshold':20, 'cuda':'2'})
autoencoder_helper.LSTM_AE_Complete(**{'grey_data_range':[1,25],  'grey_data_train_threshold':25, 'cuda':'2'})
autoencoder_helper.LSTM_AE_Complete(**{'grey_data_range':[11,25], 'grey_data_train_threshold':10, 'cuda':'3'})
autoencoder_helper.LSTM_AE_Complete(**{'grey_data_range':[11,25], 'grey_data_train_threshold':15, 'cuda':'2'})


autoencoder_helper.LSTM_AE_Complete(**{'grey_data_range':[16,25], 'grey_data_train_threshold':25, 'cuda':'1'})
autoencoder_helper.LSTM_AE_Complete(**{'grey_data_range':[16,25], 'grey_data_train_threshold':20, 'cuda':'3'})

           
    
autoencoder_helper.LSTM_AE_Complete(**{'grey_data_range':[16,25], 'grey_data_train_threshold':20, 'cuda':'3'})
autoencoder_helper.LSTM_AE_Complete(**{'grey_data_range':[16,25], 'grey_data_train_threshold':25, 'cuda':'2'})


autoencoder_helper.LSTM_AE_Complete(**{'grey_data_range':[16,25], 'grey_data_train_threshold':25, 'cuda':'1'})
autoencoder_helper.LSTM_AE_Complete(**{'grey_data_range':[16,25], 'grey_data_train_threshold':20, 'cuda':'3'})


autoencoder_helper.LSTM_AE_Complete(**{'grey_data_range':[16,25], 'grey_data_train_threshold':15, 'cuda':'2'})
autoencoder_helper.LSTM_AE_Complete(**{'grey_data_range':[16,25], 'grey_data_train_threshold':20, 'cuda':'3'})
autoencoder_helper.LSTM_AE_Complete(**{'grey_data_range':[16,25], 'grey_data_train_threshold':25, 'cuda':'2'})


autoencoder_helper.LSTM_AE_Complete(**{'grey_data_range':[11,35], 'grey_data_train_threshold':30, 'cuda':'3'})
autoencoder_helper.LSTM_AE_Complete(**{'grey_data_range':[11,35], 'grey_data_train_threshold':35, 'cuda':'2'})
autoencoder_helper.LSTM_AE_Complete(**{'grey_data_range':[16,35], 'grey_data_train_threshold':25, 'cuda':'3'})

# %%
# %reset -f 
import os, sys, imp
sys.path.append('/home/seyedkazemi/codes/mskhelper/')
sys.path.append('/home/seyedkazemi/codes/Marconi100/DNN/')
import pandas as pd, numpy as np
import datetime, pytz
import data_provider, mohsenutils, m100_preprocessing_helper, flag_helper, autoencoder_helper
import imp 
from  matplotlib import pyplot as plt
import torch 
import torch.nn as nn
import torch.functional as f
from torch.utils.data import DataLoader, Dataset
from torchinfo import summary
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from contextlib import redirect_stdout
import json
import datetime, pytz
import random
import function_set as fn
from contextlib import redirect_stdout
from pickle import dump
imp.reload(data_provider)
imp.reload(mohsenutils)
imp.reload(m100_preprocessing_helper)
imp.reload(flag_helper)
imp.reload(autoencoder_helper)

autoencoder_helper.LSTM_AE_Complete_Monthly(**{'cuda':'3', 'start_train':'2021-04-15 00:00:00', 'stop_train':'2021-05-15 00:00:00', 'grey_data_range' = [11,35], 'grey_data_train_threshold':30})
autoencoder_helper.LSTM_AE_Complete_Monthly(**{'cuda':'3', 'start_train':'2021-05-01 00:00:00', 'stop_train':'2021-06-01 00:00:00', 'grey_data_range' = [11,35], 'grey_data_train_threshold':30})
autoencoder_helper.LSTM_AE_Complete_Monthly(**{'cuda':'3', 'start_train':'2021-05-15 00:00:00', 'stop_train':'2021-06-15 00:00:00', 'grey_data_range' = [11,35], 'grey_data_train_threshold':30})
autoencoder_helper.LSTM_AE_Complete_Monthly(**{'cuda':'3', 'start_train':'2021-06-01 00:00:00', 'stop_train':'2021-07-01 00:00:00', 'grey_data_range' = [11,35], 'grey_data_train_threshold':30})
autoencoder_helper.LSTM_AE_Complete_Monthly(**{'cuda':'3', 'start_train':'2021-06-15 00:00:00', 'stop_train':'2021-07-15 00:00:00', 'grey_data_range' = [11,35], 'grey_data_train_threshold':30})
autoencoder_helper.LSTM_AE_Complete_Monthly(**{'cuda':'3', 'start_train':'2021-07-01 00:00:00', 'stop_train':'2021-08-01 00:00:00', 'grey_data_range' = [11,35], 'grey_data_train_threshold':30})

# %%
# %reset -f 
import os, sys, imp
sys.path.append('/home/seyedkazemi/codes/mskhelper/')
sys.path.append('/home/seyedkazemi/codes/Marconi100/DNN/')
import pandas as pd, numpy as np
import datetime, pytz
import data_provider, mohsenutils, m100_preprocessing_helper, flag_helper, autoencoder_helper
import imp 
from  matplotlib import pyplot as plt
import torch 
import torch.nn as nn
import torch.functional as f
from torch.utils.data import DataLoader, Dataset
from torchinfo import summary
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from contextlib import redirect_stdout
import json
import datetime, pytz
import random
import function_set as fn
from contextlib import redirect_stdout
from pickle import dump
imp.reload(data_provider)
imp.reload(mohsenutils)
imp.reload(m100_preprocessing_helper)
imp.reload(flag_helper)
imp.reload(autoencoder_helper)
# 

# autoencoder_helper.LSTM_AE_Complete_Monthly(**{'cuda':'3', 'start_train':'2021-06-15 00:00:00', 'stop_train':'2021-07-15 00:00:00', 'grey_data_range':[11,25], 'grey_data_train_threshold':15, 'dir_name':''})

autoencoder_helper.LSTM_AE_Complete_Monthly(**{'cuda':'2', 'start_train':'2021-06-22 00:00:00', 'stop_train':'2021-07-22 00:00:00', 'grey_data_range':[1,25], 'grey_data_train_threshold':20, 'dir_name':''})

# %%
# %reset -f 
import os, sys, imp
sys.path.append('/home/seyedkazemi/codes/mskhelper/')
sys.path.append('/home/seyedkazemi/codes/Marconi100/DNN/')
import pandas as pd, numpy as np
import datetime, pytz
import data_provider, mohsenutils, m100_preprocessing_helper, flag_helper, autoencoder_helper
import imp 
from  matplotlib import pyplot as plt
import torch 
import torch.nn as nn
import torch.functional as f
from torch.utils.data import DataLoader, Dataset
from torchinfo import summary
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from contextlib import redirect_stdout
import json
import datetime, pytz
import random
import function_set as fn
from contextlib import redirect_stdout
from pickle import dump
imp.reload(data_provider)
imp.reload(mohsenutils)
imp.reload(m100_preprocessing_helper)
imp.reload(flag_helper)
imp.reload(autoencoder_helper)
# 

# autoencoder_helper.LSTM_AE_Complete_Monthly(**{'cuda':'3', 'start_train':'2021-06-15 00:00:00', 'stop_train':'2021-07-15 00:00:00', 'grey_data_range':[11,25], 'grey_data_train_threshold':15, 'dir_name':''})

autoencoder_helper.LSTM_AE_Complete_Monthly(**{'cuda':'2', 'start_train':'2021-06-22 00:00:00', 'stop_train':'2021-07-22 00:00:00', 'grey_data_range':[1,25], 'grey_data_train_threshold':15, 'dir_name':''})
autoencoder_helper.LSTM_AE_Complete_Monthly(**{'cuda':'2', 'start_train':'2021-06-22 00:00:00', 'stop_train':'2021-07-22 00:00:00', 'grey_data_range':[1,25], 'grey_data_train_threshold':25, 'dir_name':''})
autoencoder_helper.LSTM_AE_Complete_Monthly(**{'cuda':'2', 'start_train':'2021-06-22 00:00:00', 'stop_train':'2021-07-22 00:00:00', 'grey_data_range':[11,25], 'grey_data_train_threshold':10, 'dir_name':''})

# %%
# %reset -f 
import os, sys, imp
sys.path.append('/home/seyedkazemi/codes/mskhelper/')
sys.path.append('/home/seyedkazemi/codes/Marconi100/DNN/')
import pandas as pd, numpy as np
import datetime, pytz
import data_provider, mohsenutils, m100_preprocessing_helper, flag_helper, autoencoder_helper
import imp 
from  matplotlib import pyplot as plt
import torch 
import torch.nn as nn
import torch.functional as f
from torch.utils.data import DataLoader, Dataset
from torchinfo import summary
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from contextlib import redirect_stdout
import json
import datetime, pytz
import random
import function_set as fn
from contextlib import redirect_stdout
from pickle import dump
imp.reload(data_provider)
imp.reload(mohsenutils)
imp.reload(m100_preprocessing_helper)
imp.reload(flag_helper)
imp.reload(autoencoder_helper)

autoencoder_helper.LSTM_AE_Complete_Monthly(**{'cuda':'3', 'start_train':'2021-04-08 00:00:00', 'stop_train':'2021-07-01 00:00:00', 'grey_data_range':[1,25], 'grey_data_train_threshold':0, 'dir_name':''})
autoencoder_helper.LSTM_AE_Complete_Monthly(**{'cuda':'3', 'start_train':'2021-04-08 00:00:00', 'stop_train':'2021-07-01 00:00:00', 'grey_data_range':[1,25], 'grey_data_train_threshold':5, 'dir_name':''})
autoencoder_helper.LSTM_AE_Complete_Monthly(**{'cuda':'2', 'start_train':'2021-04-08 00:00:00', 'stop_train':'2021-07-01 00:00:00', 'grey_data_range':[1,25], 'grey_data_train_threshold':10, 'dir_name':''})
autoencoder_helper.LSTM_AE_Complete_Monthly(**{'cuda':'3', 'start_train':'2021-04-08 00:00:00', 'stop_train':'2021-07-01 00:00:00', 'grey_data_range':[1,25], 'grey_data_train_threshold':15, 'dir_name':''})
autoencoder_helper.LSTM_AE_Complete_Monthly(**{'cuda':'3', 'start_train':'2021-04-08 00:00:00', 'stop_train':'2021-07-01 00:00:00', 'grey_data_range':[1,25], 'grey_data_train_threshold':20, 'dir_name':''})
autoencoder_helper.LSTM_AE_Complete_Monthly(**{'cuda':'3', 'start_train':'2021-04-08 00:00:00', 'stop_train':'2021-07-01 00:00:00', 'grey_data_range':[1,25], 'grey_data_train_threshold':25, 'dir_name':''})

# %%
# %reset -f 
import os, sys, imp
sys.path.append('/home/seyedkazemi/codes/mskhelper/')
sys.path.append('/home/seyedkazemi/codes/Marconi100/DNN/')
import pandas as pd, numpy as np
import datetime, pytz
import data_provider, mohsenutils, m100_preprocessing_helper, flag_helper, autoencoder_helper
import imp 
from  matplotlib import pyplot as plt
import torch 
import torch.nn as nn
import torch.functional as f
from torch.utils.data import DataLoader, Dataset
from torchinfo import summary
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from contextlib import redirect_stdout
import json
import datetime, pytz
import random
import function_set as fn
from contextlib import redirect_stdout
from pickle import dump
imp.reload(data_provider)
imp.reload(mohsenutils)
imp.reload(m100_preprocessing_helper)
imp.reload(flag_helper)
imp.reload(autoencoder_helper)
autoencoder_helper.LSTM_AE_Complete_Monthly(**{'cuda':'3', 'start_train':'2021-04-08 00:00:00', 'stop_train':'2021-07-15 00:00:00', 'grey_data_range':[1,25], 'grey_data_train_threshold':15, 'dir_name':''})
