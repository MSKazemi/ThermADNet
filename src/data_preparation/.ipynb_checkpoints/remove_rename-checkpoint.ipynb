# %%
import os, glob, shutil

# 

metric_lst = ['gpu0_core_temp','gpu0_mem_temp','gpu1_core_temp','gpu1_mem_temp','gpu3_core_temp','gpu3_mem_temp','gpu4_core_temp','gpu4_mem_temp',
              'p0_core0_temp','p0_core10_temp','p0_core11_temp','p0_core12_temp','p0_core13_temp','p0_core14_temp','p0_core15_temp','p0_core16_temp',
              'p0_core17_temp','p0_core18_temp','p0_core19_temp','p0_core1_temp','p0_core20_temp','p0_core21_temp','p0_core22_temp','p0_core23_temp',
              'p0_core2_temp','p0_core3_temp','p0_core4_temp','p0_core5_temp','p0_core6_temp','p0_core7_temp','p0_core8_temp','p0_core9_temp',
              'p1_core0_temp','p1_core10_temp','p1_core11_temp','p1_core12_temp','p1_core13_temp','p1_core14_temp','p1_core15_temp','p1_core16_temp',
              'p1_core17_temp','p1_core18_temp','p1_core19_temp','p1_core1_temp','p1_core20_temp','p1_core21_temp','p1_core22_temp','p1_core23_temp',
              'p1_core2_temp','p1_core3_temp','p1_core4_temp','p1_core5_temp','p1_core6_temp','p1_core7_temp','p1_core8_temp','p1_core9_temp']

for metric in metric_lst:
    for files in glob.glob('/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/'+str(metric)+'/'+str(metric)+'_pivot/*'):
        print(files)

# %%
import os, glob, shutil

# 

# metric_lst = ['gpu0_core_temp','gpu0_mem_temp','gpu1_core_temp','gpu1_mem_temp','gpu3_core_temp','gpu3_mem_temp','gpu4_core_temp','gpu4_mem_temp',
#               'p0_core0_temp','p0_core10_temp','p0_core11_temp','p0_core12_temp','p0_core13_temp','p0_core14_temp','p0_core15_temp','p0_core16_temp',
#               'p0_core17_temp','p0_core18_temp','p0_core19_temp','p0_core1_temp','p0_core20_temp','p0_core21_temp','p0_core22_temp','p0_core23_temp',
#               'p0_core2_temp','p0_core3_temp','p0_core4_temp','p0_core5_temp','p0_core6_temp','p0_core7_temp','p0_core8_temp','p0_core9_temp',
#               'p1_core0_temp','p1_core10_temp','p1_core11_temp','p1_core12_temp','p1_core13_temp','p1_core14_temp','p1_core15_temp','p1_core16_temp',
#               'p1_core17_temp','p1_core18_temp','p1_core19_temp','p1_core1_temp','p1_core20_temp','p1_core21_temp','p1_core22_temp','p1_core23_temp',
#               'p1_core2_temp','p1_core3_temp','p1_core4_temp','p1_core5_temp','p1_core6_temp','p1_core7_temp','p1_core8_temp','p1_core9_temp']

metric_lst = ['p0_core0_temp','p0_core10_temp','p0_core11_temp','p0_core12_temp','p0_core13_temp','p0_core14_temp','p0_core15_temp','p0_core16_temp',
              'p0_core17_temp','p0_core18_temp','p0_core19_temp','p0_core1_temp','p0_core20_temp','p0_core21_temp','p0_core22_temp','p0_core23_temp',
              'p0_core2_temp','p0_core3_temp','p0_core4_temp','p0_core5_temp','p0_core6_temp','p0_core7_temp','p0_core8_temp','p0_core9_temp',
              'p1_core0_temp','p1_core10_temp','p1_core11_temp','p1_core12_temp','p1_core13_temp','p1_core14_temp','p1_core15_temp','p1_core16_temp',
              'p1_core17_temp','p1_core18_temp','p1_core19_temp','p1_core1_temp','p1_core20_temp','p1_core21_temp','p1_core22_temp','p1_core23_temp',
              'p1_core2_temp','p1_core3_temp','p1_core4_temp','p1_core5_temp','p1_core6_temp','p1_core7_temp','p1_core8_temp','p1_core9_temp']


for metric in metric_lst:
    for files in glob.glob('/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/'+str(metric)+'/'+str(metric)+'_pivot_done/*'):
        try:
            shutil.move(files, '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/'+str(metric)+'/'+str(metric)+'_pivot/')
        except Exception as e:
            print(e)

# %%
for metric in metric_lst:
    try:
        path = '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/'+str(metric)+'/'+str(metric)+'_pivot_done/'
        print(len(os.listdir(path)))
        if len(os.listdir(path))==0:
            os.rmdir(path)
#             pass
        else:
            print(path)
    
    except Exception as e:
        print(e)
# Out:
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p0_core0_temp/p0_core0_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p0_core10_temp/p0_core10_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p0_core11_temp/p0_core11_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p0_core12_temp/p0_core12_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p0_core13_temp/p0_core13_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p0_core14_temp/p0_core14_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p0_core15_temp/p0_core15_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p0_core16_temp/p0_core16_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p0_core17_temp/p0_core17_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p0_core18_temp/p0_core18_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p0_core19_temp/p0_core19_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p0_core1_temp/p0_core1_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p0_core20_temp/p0_core20_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p0_core21_temp/p0_core21_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p0_core22_temp/p0_core22_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p0_core23_temp/p0_core23_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p0_core2_temp/p0_core2_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p0_core3_temp/p0_core3_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p0_core4_temp/p0_core4_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p0_core5_temp/p0_core5_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p0_core6_temp/p0_core6_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p0_core7_temp/p0_core7_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p0_core8_temp/p0_core8_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p0_core9_temp/p0_core9_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p1_core0_temp/p1_core0_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p1_core10_temp/p1_core10_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p1_core11_temp/p1_core11_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p1_core12_temp/p1_core12_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p1_core13_temp/p1_core13_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p1_core14_temp/p1_core14_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p1_core15_temp/p1_core15_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p1_core16_temp/p1_core16_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p1_core17_temp/p1_core17_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p1_core18_temp/p1_core18_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p1_core19_temp/p1_core19_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p1_core1_temp/p1_core1_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p1_core20_temp/p1_core20_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p1_core21_temp/p1_core21_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p1_core22_temp/p1_core22_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p1_core23_temp/p1_core23_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p1_core2_temp/p1_core2_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p1_core3_temp/p1_core3_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p1_core4_temp/p1_core4_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p1_core5_temp/p1_core5_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p1_core6_temp/p1_core6_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p1_core7_temp/p1_core7_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p1_core8_temp/p1_core8_temp_pivot_done/'
# [Errno 2] No such file or directory: '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/p1_core9_temp/p1_core9_temp_pivot_done/'

# %%
# for metric in metric_lst:
#     os.rename('/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/'+str(metric)+'/'+str(metric)+'_pivot_new/', 
#               '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/'+str(metric)+'/'+str(metric)+'_pivot/')

# %%
path = '/home/seyedkazemi/dataset/Marconi100_backup/ipmi_pub/gpu0_core_temp/gpu0_core_temp_pivot/'

metric_lst = ['gpu0_core_temp',
 'gpu0_mem_temp',
 'gpu1_core_temp',
 'gpu1_mem_temp',
 'gpu3_core_temp',
 'gpu3_mem_temp',
 'gpu4_core_temp',
 'gpu4_mem_temp',
 'p0_core0_temp',
 'p0_core10_temp',
 'p0_core11_temp',
 'p0_core12_temp',
 'p0_core13_temp',
 'p0_core14_temp',
 'p0_core15_temp',
 'p0_core16_temp',
 'p0_core17_temp',
 'p0_core18_temp',
 'p0_core19_temp',
 'p0_core1_temp',
 'p0_core20_temp',
 'p0_core21_temp',
 'p0_core22_temp',
 'p0_core23_temp',
 'p0_core2_temp',
 'p0_core3_temp',
 'p0_core4_temp',
 'p0_core5_temp',
 'p0_core6_temp',
 'p0_core7_temp',
 'p0_core8_temp',
 'p0_core9_temp',
 'p1_core0_temp',
 'p1_core10_temp',
 'p1_core11_temp',
 'p1_core12_temp',
 'p1_core13_temp',
 'p1_core14_temp',
 'p1_core15_temp',
 'p1_core16_temp',
 'p1_core17_temp',
 'p1_core18_temp',
 'p1_core19_temp',
 'p1_core1_temp',
 'p1_core20_temp',
 'p1_core21_temp',
 'p1_core22_temp',
 'p1_core23_temp',
 'p1_core2_temp',
 'p1_core3_temp',
 'p1_core4_temp',
 'p1_core5_temp',
 'p1_core6_temp',
 'p1_core7_temp',
 'p1_core8_temp',
 'p1_core9_temp']
